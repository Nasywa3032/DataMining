# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# 1. Preprocessing
print("="*30)
print("1. Preprocessing")
print("="*30)

# a. Tampilkan ringkasan statistik
df = pd.read_csv('data_pelanggan.csv')
print("\nRingkasan Statistik:")
print(data.describe())

# b. Visualisasikan hubungan antara pendapatan dan pembelian_tahunan
plt.figure(figsize=(8, 6))
sns.scatterplot(x='pendapatan', y='pembelian_tahunan', hue='umur', data=data)
plt.title('Hubungan antara Pendapatan dan Pembelian Tahunan')
plt.xlabel('Pendapatan')
plt.ylabel('Pembelian Tahunan')
plt.grid(True)
plt.show()
# Out:
# ...
# 1. Preprocessing
# ...
#
# Ringkasan Statistik:
#              umur  pendapatan  pembelian_tahunan
# count  100.000000  100.000000         100.000000
# mean    38.790000   27.800000           6.660000
# std     11.556008   17.077364           3.929222
# min     20.000000    0.000000           1.000000
# 25%     28.000000   14.750000           3.000000
# 50%     39.500000   27.500000           6.000000
# 75%     47.250000   40.250000           9.000000
# max     59.000000   57.000000          14.000000

# %%
print("\nMissing values:\n" , df.isnull().sum)
df.columns

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

# %%
df['Label'] = df['umur'].apply(lambda x: 1 if x > 0 else 0)
features = df[['pendapatan', 'pembelian_tahunan']].fillna(0)
labels = df['Label']

# %%
x_train, x_test, y_train, y_test, = train_test_split(features, labels, test_size=0.3, random_state=42)
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
y_pred = model.predict(x_test)

# %%
print("classification report :\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# classification report :
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        30
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# Confusion Matrix:
#  [[30]]
# C:\Users\nasyw\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %% [markdown]
# Berdasarkan
#
# # **PENJELASAN**
#
# Model klasifikasi ini dibuat untuk memprediksi apakah suatu transaksi menghasilkan keuntungan (label: 1) atau mengalami kerugian (label: 0). Model yang digunakan adalah Decission Tree, dan performanya diukur dengan Classification Report dan Confusion Matrix.
#
# 1. Precision
# (Ukuran seberapa tepat prediksi kelas itu.)
#
# Precision kelas 0 (rugi):
# → Dari seluruh prediksi "rugi", % benar-benar rugi.
#
# Precision kelas 1 (untung): 1.00
# → Dari seluruh prediksi "untung", 100% benar-benar untung.
#
# 2. Recall
# (Ukuran seberapa banyak kasus aktual yang berhasil ditemukan.)
#
# Recall kelas 0 (rugi):
# → Dari semua transaksi yang sebenarnya rugi, % berhasil terdeteksi.
#
# Recall kelas 1 (untung): 1.00
# → Dari semua transaksi yang sebenarnya untung, 100% berhasil dikenali.
#
# 3. F1-Score
# Kombinasi precision dan recall (semakin mendekati 1 semakin baik).
#
# F1 untuk kelas 0: 1.00 artinya model lebih kuat dalam memprediksi keuntungan.
#
# 4. Support
# Jumlah data sebenarnya untuk tiap kelas.
#
# Rugi: , Untung: 30 (berarti data tidak seimbang, lebih banyak transaksi untung).
#
# Accuracy (akurasi keseluruhan): 100% prediksi benar.

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
df['Label'] = df['Profit'].apply(lambda x: 1 if x > 0 else 0)
features = df[['Sales', 'Discount', 'Quantity']].fillna(0)
labels = df['Label']

X_train, X_test, y_train, y_test, = train_test_split(features, labels, test_size=0.3, random_state=42)
model = KNeighborsClassifier()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)

print("KNN (K Nearest Neighbour)")
print("Classification Report :\n", classification_report(y_test, y_pred))
print("Confusion Matrix :\n", confusion_matrix(y_test, y_pred))
# Out:
# KNN (K Nearest Neighbour)
# Classification Report :
#                precision    recall  f1-score   support
#
#            1       1.00      1.00      1.00        30
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
# Confusion Matrix :
#  [[30]]
# C:\Users\nasyw\AppData\Roaming\Python\Python312\site-packages\sklearn\metrics\_classification.py:407: UserWarning: A single label was found in 'y_true' and 'y_pred'. For the confusion matrix to have the correct shape, use the 'labels' parameter to pass all known labels.
#   warnings.warn(

# %% [markdown]
# Berdasarkan
#
# # **PENJELASAN**
#
# Model klasifikasi ini dibuat untuk memprediksi apakah suatu transaksi menghasilkan keuntungan (label: 1) atau mengalami kerugian (label: 0). Model yang digunakan adalah knn, dan performanya diukur dengan Classification Report dan Confusion Matrix.
#
# 1. Precision
# (Ukuran seberapa tepat prediksi kelas itu.)
#
# Precision kelas 0 (rugi):
# → Dari seluruh prediksi "rugi", % benar-benar rugi.
#
# Precision kelas 1 (untung): 1.00
# → Dari seluruh prediksi "untung", 100% benar-benar untung.
#
# 2. Recall
# (Ukuran seberapa banyak kasus aktual yang berhasil ditemukan.)
#
# Recall kelas 0 (rugi):
# → Dari semua transaksi yang sebenarnya rugi, % berhasil terdeteksi.
#
# Recall kelas 1 (untung): 1.00
# → Dari semua transaksi yang sebenarnya untung, 100% berhasil dikenali.
#
# 3. F1-Score
# Kombinasi precision dan recall (semakin mendekati 1 semakin baik).
#
# F1 untuk kelas 0: 1.00 artinya model lebih kuat dalam memprediksi keuntungan.
#
# 4. Support
# Jumlah data sebenarnya untuk tiap kelas.
#
# Rugi: , Untung: 30 (berarti data tidak seimbang, lebih banyak transaksi untung).
#
# Accuracy (akurasi keseluruhan): 100% prediksi benar.

# %% [markdown]
# Model klasifikasi Decision Tree yang digunakan berhasil memprediksi transaksi dengan akurasi 100%, ditunjukkan oleh nilai precision, recall, dan F1-score sebesar 1.00 untuk kelas "untung". Namun, tidak terdapat informasi lengkap tentang performa untuk kelas "rugi", dan jumlah data juga tidak seimbang (lebih banyak transaksi untung), sehingga perlu kehati-hatian dalam menilai performa model secara menyeluruh. Evaluasi tambahan diperlukan, terutama pada prediksi kelas "rugi"
